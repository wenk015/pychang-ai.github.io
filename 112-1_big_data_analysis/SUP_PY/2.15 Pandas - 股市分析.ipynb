# %%
! pip install --upgrade pandas-datareader
! pip install yfinance
# Out:
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
#      ---------------------------------------- 0.0/109.5 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/109.5 kB ? eta -:--:--
#      ----------------------------------- -- 102.4/109.5 kB 1.2 MB/s eta 0:00:01
#      -------------------------------------- 109.5/109.5 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: lxml in d:\anaconda3\envs\bigdata\lib\site-packages (from pandas-datareader) (4.9.3)
# Requirement already satisfied: pandas>=0.23 in d:\anaconda3\envs\bigdata\lib\site-packages (from pandas-datareader) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in d:\anaconda3\envs\bigdata\lib\site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda3\envs\bigdata\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda3\envs\bigdata\lib\site-packages (from pandas>=0.23->pandas-datareader) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda3\envs\bigdata\lib\site-packages (from pandas>=0.23->pandas-datareader) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in d:\anaconda3\envs\bigdata\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.24.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\envs\bigdata\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\bigdata\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\envs\bigdata\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\bigdata\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2023.7.22)
# Requirement already satisfied: six>=1.5 in d:\anaconda3\envs\bigdata\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.10.0
# Collecting yfinance
#   Downloading yfinance-0.2.33-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=1.3.0 in d:\anaconda3\envs\bigdata\lib\site-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in d:\anaconda3\envs\bigdata\lib\site-packages (from yfinance) (1.24.4)
# Requirement already satisfied: requests>=2.31 in d:\anaconda3\envs\bigdata\lib\site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in d:\anaconda3\envs\bigdata\lib\site-packages (from yfinance) (4.9.3)
# Collecting appdirs>=1.4.4 (from yfinance)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pytz>=2022.5 in d:\anaconda3\envs\bigdata\lib\site-packages (from yfinance) (2023.3.post1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.3.10-cp38-cp38-win_amd64.whl.metadata (21 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.0.tar.gz (2.9 MB)
#      ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#       --------------------------------------- 0.1/2.9 MB 2.0 MB/s eta 0:00:02
#      ---- ----------------------------------- 0.3/2.9 MB 3.8 MB/s eta 0:00:01
#      --------- ------------------------------ 0.7/2.9 MB 5.5 MB/s eta 0:00:01
#      ---------------------- ----------------- 1.7/2.9 MB 10.6 MB/s eta 0:00:01
#      -------------------------------------- - 2.8/2.9 MB 12.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.9/2.9 MB 12.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\anaconda3\envs\bigdata\lib\site-packages (from yfinance) (4.12.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#      ---------------------------------------- 112.2/112.2 kB ? eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in d:\anaconda3\envs\bigdata\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in d:\anaconda3\envs\bigdata\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Collecting webencodings (from html5lib>=1.1->yfinance)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\anaconda3\envs\bigdata\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in d:\anaconda3\envs\bigdata\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda3\envs\bigdata\lib\site-packages (from requests>=2.31->yfinance) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda3\envs\bigdata\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda3\envs\bigdata\lib\site-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda3\envs\bigdata\lib\site-packages (from requests>=2.31->yfinance) (2023.7.22)
# Downloading yfinance-0.2.33-py2.py3-none-any.whl (69 kB)
#    ---------------------------------------- 0.0/69.0 kB ? eta -:--:--
#    ---------------------------------------- 69.0/69.0 kB ? eta 0:00:00
# Downloading frozendict-2.3.10-cp38-cp38-win_amd64.whl (35 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.0-py3-none-any.whl size=135766 sha256=ba466f8d3f2b3247bbc05c496b2cdc24d0648df708cadd46c2e3efc779eb3bdd
#   Stored in directory: c:\users\pyc\appdata\local\pip\cache\wheels\8a\2c\db\72c95212e78c98614b5f89978fc5d68a67e39ea7701fc8c504
# Successfully built peewee
# Installing collected packages: webencodings, peewee, multitasking, appdirs, html5lib, frozendict, yfinance
# Successfully installed appdirs-1.4.4 frozendict-2.3.10 html5lib-1.1 multitasking-0.0.11 peewee-3.17.0 webencodings-0.5.1 yfinance-0.2.33

# %%
from pandas_datareader import data
import yfinance as yf
yf.pdr_override() 
df = data.get_data_yahoo(['2330.TW','2454.TW','1326.TW','2049.TW'],'2013-01-01')['Close']
df.columns = ['台積','聯發科','台化','上銀']
df.head()
# Out:
# [*********************100%%**********************]  4 of 4 completed
#                    台積         聯發科          台化     上銀
# Date
# 2013-01-02  73.203880  166.423492   99.599998  325.0
# 2013-01-03  75.533981  168.349686  101.000000  326.0
# 2013-01-04  76.310677  166.038239  101.500000  305.5
# 2013-01-07  76.213593  160.644897  100.500000  301.5
# 2013-01-08  76.116501  159.103928   99.699997  302.5

# %%
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# plt.rcParams['font.sans-serif'] = ['DFKai-sb']
# %config InlineBackend.figure_format = 'retina'
import warnings
warnings.filterwarnings('ignore')
